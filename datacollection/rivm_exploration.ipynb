# %%
# default libs
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# geo dfs
import pandas as pd
import geopandas as gpd
import contextily as cx
# raster data
import rioxarray as rxr
import rasterio as rio

# %%
lden_rasters = rxr.open_rasterio('..\\data\\rivm-lden\\rivm_20220601_Geluid_lden_allebronnen_2020_v2.tif', masked=True).squeeze()
print(lden_rasters.shape)
print(lden_rasters[0][54].values)
# ['band']['y']['x']
# Out:
# (31200, 26400)
# nan

# %%
lden_rasters = lden_rasters.rio.clip_box(minx=129739.1234,miny=450112.6341,
                                         maxx=142817.4583,maxy=461586.9908)

# %%
lden_rasters.plot()

# %%
lden_rasters.rio.crs
# Out:
# CRS.from_epsg(28992)

# %%
lden_rasters.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 lden_rasters.plot()
#
# File c:\Users\flori\!projects\noise-these\noise-thesis\.venv\Lib\site-packages\xarray\plot\accessor.py:48, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      46 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      47 def __call__(self, **kwargs) -> Any:
# ---> 48     return dataarray_plot.plot(self._da, **kwargs)
#
# File c:\Users\flori\!projects\noise-these\noise-thesis\.venv\Lib\site-packages\xarray\plot\dataarray_plot.py:309, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     305     plotfunc = hist
#     307 kwargs["ax"] = ax
# --> 309 return plotfunc(darray, **kwargs)
#
# ...

# %%
f, ax = plt.subplots(figsize=(10, 6))
lden_rasters.plot.hist(color="purple",
                      bins=20)
ax.set_title("Histogram of the Data with No Data Values Removed")
plt.show()
