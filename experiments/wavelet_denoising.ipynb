# %%
import soundfile as sf
from IPython.display import Audio

# %%
# step 1: Read an audio signal x(i)
# x_i, sr = sf.read('../data/gopro-clipped/30kmph_short.wav')
x_audio, sr = sf.read('../data/clean.wav')

print(x_audio)
print(x_audio.shape)
print(len(x_audio))
# Out:
# [-1.86157227e-03 -1.70898438e-03 -1.73950195e-03 ... -1.52587891e-04
#  -3.05175781e-05 -2.44140625e-04]
# (673947,)
# 673947

# %%
# step 2: add gaussion noise to the signal to form signal y(i).
n = len(x_audio)
i = [j for j in range(len(x_audio))]
sigma = pass # noise intensity
eta_i = pass # noise signal
y_audio = x_audio + sigma * eta_i

# %%
Audio(data=x_audio, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
