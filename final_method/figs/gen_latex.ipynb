# %%
import os
import sys
import re

os.listdir()
# Out:
# ['dBA_dual_red-all.png',
#  'dBA_dual_red-lun.png',
#  'dBA_dual_red_slt20-all.png',
#  'dBA_dual_red_slt20-lun.png',
#  'dBA_noise_red-all.png',
#  'dBA_noise_red-lun.png',
#  'dBA_noise_red_slt20-all.png',
#  'dBA_noise_red_slt20-lun.png',
#  'dBA_raw-all.png',
#  'dBA_raw-lun.png',
#  'dBA_raw_slt20-all.png',
#  'dBA_raw_slt20-lun.png',
#  'dBA_reg_adj-all.png',
#  'dBA_reg_adj-lun.png',
#  'dBA_reg_adj_slt20-all.png',
#  'dBA_reg_adj_slt20-lun.png',
#  'gen_latex.ipynb']

# %%
for ar in ('all', 'lun'):
    for slt in ('', '_slt20'):
        for db in ('dBA_raw', 'dBA_noise_red', 'dBA_reg_adj', 'dBA_dual_red'):
            
            # print(dbp)
            filename = f'diff-{db}{slt}-{ar}'
            caption = f'Difference between reference dBA values and predictions for {db}{slt} (trained on {'Lunnetten sub-area' if ar=='lun' else 'all areas'})'
            caption = re.sub(r'\_', r'\\textunderscore ', caption)
            print(f'\\begin{{figure}}[htbp]\n    \\centering\n    \\includegraphics[width=\\textwidth]{{images/appendixB-diffGraphs/{filename}.png}}\n    \\caption{{{caption}}}\n    \\label{{fig:{filename}}}\n\\end{{figure}}')
            print()
# Out:
# \begin{figure}[htbp]
#     \centering
#     \includegraphics[width=\textwidth]{images/appendixB-diffGraphs/diff-dBA_raw-all.png}
#     \caption{Difference between reference dBA values and predictions for dBA\textunderscore raw (trained on all areas)}
#     \label{fig:diff-dBA_raw-all}
# \end{figure}
#
# \begin{figure}[htbp]
#     \centering
#     \includegraphics[width=\textwidth]{images/appendixB-diffGraphs/diff-dBA_noise_red-all.png}
#     \caption{Difference between reference dBA values and predictions for dBA\textunderscore noise\textunderscore red (trained on all areas)}
#     \label{fig:diff-dBA_noise_red-all}
# \end{figure}
#
# \begin{figure}[htbp]
#     \centering
#     \includegraphics[width=\textwidth]{images/appendixB-diffGraphs/diff-dBA_reg_adj-all.png}
#     \caption{Difference between reference dBA values and predictions for dBA\textunderscore reg\textunderscore adj (trained on all areas)}
#     \label{fig:diff-dBA_reg_adj-all}
# \end{figure}
#
# \begin{figure}[htbp]
# ...

# %%
""""
\section{appendix A}
\begin{figure}[htbp]
    \centering
    \includegraphics[width=\textwidth]{images/dbarawanyfull.png}
    \caption{aaaaahhh}
    \label{fig:test1}
\end{figure}
"""
